# %% [markdown]
# # Manejo de rutas: problemática

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hay un problema en que Windows y Linux manejan de diferente forma el S.O. Por lo que puede resultar un problema cuando queramos implementar este tipo de soluciones de plantilla.
#
# Ejemplifiquemos lo que queremos decir.
#
# Escojamos un lugar diferente de ruta para bajar nuestro proyecto.
#
# Recordemos tener activado el entorno donde tenemos cookicutter y corramos lo siguiente:
#
# ```bash
# #activar el entorno de cookiecutter
# conda activate env
# #descargar la plantilla y crear un proyecto
# cookiecutter git@github.com:DensLopez/cookiecutter_template.git
# #Despues tenemos que  configurar el proyecto
# ```
# ![image.png](attachment:image.png)

# %% [markdown]
# Una vez que se creo todo, procedemos a abrir la carpeta en VSCode con `code manejo_de_rutas\`. Una vez dentro del programa, abrimos el archivo `environment.yml`, que contiene lo siguiente:
#
# ```yaml
# #Para poder crear un entorno en conda corremos
# #conda env create --file environment.yml
#
#
# #NOMBRE DEL PROYECTO
# name: manejo_de_rutas
# channels:
# - anaconda
# - conda-forge
# - default
# dependencies:
# #BLOQUE DECLARATIVO
# - fs
# - jupyter
# - jupyterlab
# - pathlib
# - pip
# - pyprojroot
# - python=3.10
# - pip:
#     - pyhere
# ```
# Después procedemos a abrir una terminal con el comando `ctrl + shift + P`, y ejecutamos el comando `conda env create --file environment.yml`

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Se tienen que instalar los paquetes. Una vez instalados me despliega un mensaje de conda, con las instrucciones para activar el entorno.
#
# Ya que ha finalizado, creamos un notebook en la carpeta correspondiente, activamos el entorno con `conda activate manejo_de_rutas` y por último activamos en VSCode el Kernel correspondiente a `manejo de rutas`.
#
# ![image-2.png](attachment:image-2.png)
#
# **NOTA:** En caso que no aparezca, podemos dar `ctrl + shift p` y teclear `Reload window`o también podemos cerrar VSCode y volverlo a abrir.

# %% [markdown]
# Ahora tratemos de ver como solucionar la problemática del manejo de rutas dependiendo el S.O en la siguiente clase.
